# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name: Atta Ur Rehman\nFater Name: Shafique Akbar\nDOB: 25/05/2004")
# Out:
# Name: Atta Ur Rehman
# Fater Name: Shafique Akbar
# DOB: 25/05/2004

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
Atta_Bio = "I’m a BSCS undergraduate student on a journey to Learning master Python\nby building real-world projects and sharing my learning along the way.\nPassionate about technology, problem-solving, and continuous growth,\nI aim to turn curiosity into impactful and practical solutions."
print(Atta_Bio)
# Out:
# I’m a BSCS undergraduate student on a journey to Learning master Python
# by building real-world projects and sharing my learning along the way.
# Passionate about technology, problem-solving, and continuous growth,
# I aim to turn curiosity into impactful and practical solutions.

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a=10
b=5
sum =a+b
sub= a-b
mul= a*b
div= a/b
mod= a%b
pow=a**b
op= a//b
print("Sum:",sum,"\nSubtraction:",sub,"\nMultiplication:",mul,"\nDivision:",div,"\nModulus:",mod,"\nPower:",pow,"\nfloor Division:",op)
# Out:
# Sum: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0
# Modulus: 0
# Power: 100000
# floor Division: 2

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
English=60
Islamiyat=80
Math=75
Total_Marks=300
Obtained_Marks=English+Islamiyat+Math
percentage=(Obtained_Marks/Total_Marks)*100
print(f"Total_Marks: {Total_Marks}\n"
    f"Obtaines_Marks:{Obtained_Marks}\n"
    f"Percentage:{percentage}"
    )
# Out:
# Total_Marks: 300
# Obtaines_Marks:215
# Percentage:71.66666666666667
