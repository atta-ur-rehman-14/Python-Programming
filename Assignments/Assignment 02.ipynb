# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = int(input("Enter you Monthly salary:"))
Year = int(input("Enter the number of years of your service:"))

# Logic 
# User se salary aur years of service lo
# Agar service > 5 years → 5% bonus
# Bonus = salary × 5 / 100
# Agar service ≤ 5 → no bonus (0)

Net_Bonus= 0.05 * salary
if Year > 5:
    print("Your Bonus is:",Net_Bonus)
# Out:
# Your Bonus is: 1.1

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age= int(input("Enter ypu Age:"))
if age > 17:
    print("Eligible for Voting")
else:
    print("Not Eligible for Voting")
# Out:
# Eligible for Voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num= int(input("Enter a number:"))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num= int(input("Enter a number:"))
if num % 7 ==0:
    print("Divisible by 7")
else:
    print("Not Divisible by 7")
# Out:
# Not Divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
number= int(input("Enter a number:"))
if number % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
num= int(input("Enter the number:"))
# use the modulus operator ('%') to display last digit means as remainder 
Last_digit = num % 10
print("Last digit is:",Last_digit)
# Out:
# Last digit is: 5

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
Length = float(input("Enter the Length  of a Rectangle:"))
Width = float(input("Enter the Width of a Rectangle:"))

# Logic
# Agar length == breadth → Square
# Agar length ≠ breadth → Rectangle

if Length == Width:
    print("Square")
else:
    print("Rectangle")
# Out:
# Rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
a=int(input("Enter the 1st number:"))
b=int(input("Enter the 2nd number:"))

if a > b:
    print("The greatest number is:",a)
elif b > a:
    print("The greatest number is:",b)
else:
    print("Both numbers are Equal:",a,"=",b)
# Out:
# Both numbers are Equal: 40 = 40

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
# Out:
# Total cost: 1980.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks= int(input("Enter the Marks:"))

if marks < 25:
    print("The Grade is F")
elif marks >=25 and marks <=45:
    print("The Grade is E")
elif marks >= 45 and marks <=50:
    print("The Grade is D")
elif marks >= 50 and marks <= 60:
    print("The Grade is C")
elif marks >= 60 and marks <= 80:
    print("The Grade is B")
else:
    print("The Grade is A")
# Out:
# The Grade is C

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
Classes = int(input("Enter the Classes held:"))
Attended_Classes = int(input("Enter the Classes attended:"))

Attendence_Percentage = (Attended_Classes / Classes) * 100
print("Attendence_Percentage:",Attendence_Percentage)

if Attendence_Percentage >= 75:
    print("Allowed to sit in Exam")
else:
    print("Not Allowed to sit in Exam")
# Out:
# Attendence_Percentage: 63.63636363636363 %
# Not Allowed to sit in Exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
Year= int(input("Enter the Year:"))
if (Year % 4 == 0 and Year % 100 !=0) or (Year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Not a Leap Year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
Age= int(input("Enter the Age:"))
Employee_Gender = input("Enter the Gender:")
Marial_Status = input("Enter the Martial status:")
if Employee_Gender == "F":
    print("Female EmployeeWork in Urban Areas only")
elif Employee_Gender == "M" and Age >=20 and Age <=40:
    print("Male Employee Work in Anywhere")
elif Employee_Gender == "M" and Age >=40 and Age <=60:
    print("Male Employee Work in Urban Areas only")
else:
    print("ERROR")
# Out:
# Male Employee Work in Anywhere

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1= int(input("Enter the age of 1st person:"))
age2= int(input("Enter the age of 2nd person:"))
age3=int(input("Enter the age of 3rd person:"))

Oldest= max(age1,age2,age3)
Youngest= min(age1,age2,age3)

print(f"The Oldest person is: {Oldest}",f"\nThe Youngest Person is: {Youngest}")

# print(f"Oldest person: {max(age1,age2,age3)}, Youngest person: {min(age1,age2,age3)}")
# print("Youngest person:",min(age1,age2,age3))
# Out:
# The Oldest person is: 77
# The Youngest Person is: 44
