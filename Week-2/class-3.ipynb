# %%
name="Atta Ur Rehman"
print(name)
# Out:
# Atta Ur Rehman

# %%
type(name)
# Out:
# str

# %%
id(name)
# Out:
# 3126292464368

# %%
num=20
print(num)
# Out:
# 20

# %%
type(num)
# Out:
# int

# %%
id(num)
# Out:
# 140726542890712

# %%
Weight=20.2
print(Weight)
# Out:
# 20.2

# %%
type(Weight)
# Out:
# float

# %%
id(Weight)
# Out:
# 2456711710032
