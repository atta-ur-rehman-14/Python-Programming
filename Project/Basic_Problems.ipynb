# %% [markdown]
# # Topics Covered:
# - print() function
# - Variables & data types (int, float, str, bool)
# - input() from user
# - Type conversion: int(), float(), str()

# %% [markdown]
# #### Problem 1: Print your name, age, and city in three separate lines.
# ##### Hint: Use three print() statements

# %%
Name= "Atta Ur Rehman"
Age = 22
city = "Lahore"
print("My name is",Name )
print("I am "+ str(Age) +  " years old")
print("I live in " + city)
# Out:
# My name is Atta Ur Rehman
# I am 22 years old
# I live in Lahore

# %% [markdown]
# ##### Problem 2: Ask the user for their name and age. Print: 'Hello [name], you are [age] years old!'
# ##### Hint: Use input() and string concatenation or f-strings

# %%
Name = input("Enter your name:")
Age = input("Enter your age:")
print(f"Hello {Name}, you are {Age} years old.")
# Out:
# Hello Atta, you are 22 years old.
