# %% [markdown]
# # Set

# %% [markdown]
# #### Creating set

# %%
my_set = {1,2,3,4,5,5,7,8,5,4}
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 7, 8}

# %%
my_set= set([1,2,3,4,5]) # set create using set() function

# %% [markdown]
# ### Add an Element

# %%
my_set.add(6)

# %%
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ### Remove an Element

# %%
my_set.remove(8)

# %%
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# ### Union (Combine Sets)

# %%
a= {1,3,5,7,9}
b= {3,7,2,8,1}

print(a.union(b)) # union of two sets
# Out:
# {1, 2, 3, 5, 7, 8, 9}

# %% [markdown]
# #### Intersection (Common Elements)

# %%
a= {1,3,5,7,9}
b= {3,7,2,8,1}

print(a.intersection(b)) # intersection of two set
# Out:
# {1, 3, 7}

# %%
print(a.difference(b)) # difference of two set
# Out:
# {9, 5}

# %% [markdown]
# # Match Statement

# %%
Day = 5
match Day:
    case 1:
        print("Monday")
    case 2:
        print("Tuesday")
    case 3:
        print("Wednesday")
    case 4:
        print("Thursday")
    case 5:
        print("Friday")
    case 6:
        print("Saturday")
    case 7:
        print("Sunday")
# Out:
# Friday

# %%
day = 2
match day:
    case 1|7:
        print("Weekend")
    case _:
        print("Weekday")
# Out:
# Weekday

# %%
num = 10
match num:
    case 1:
        print("one")
    case 2:
        print("two")
    case 3:
        print("three")
    case _:
        print("Invalid number")
# Out:
# Invalid number

# %%
num = 5
match num:
    case 0:
        print("Zero")
    case 1:
        print("One")
    case _:
        print("other")
# Out:
# other

# %% [markdown]
# # Calculator

# %%
a= float(input("Enter a number:"))
b = float(input("Enter another number:"))
op= input("Enter an operatoe (+,-,*,/,%)")

match op:
    case "+":
        print("Result:",a+b)
    case "-":
        print("Result:",a-b)
    case "*":
        print("Result:",a*b)
    case "/":
        print("Result:",a/b)
    case "%":
        print("Result:",a%b)
# Out:
# Result: 4.0

# %% [markdown]
# # Array

# %% [markdown]
# # Array using array module

# %% [markdown]
# - Python also has an array module for same data type values only.

# %%
import array

numbers = array.array('i', [1, 2, 3, 4])
print(numbers)
# Out:
# array('i', [1, 2, 3, 4])

# %% [markdown]
# # Datatime Module
#
# In Python, we use the datetime module to work with dates and time.
#
# - It helps us to:
#
#    - Get current date and time
#    - Create custom dates
#    - Format dates
#    - Extract parts like year, month, day

# %%
import datetime

# %%
x= datetime.datetime.now()
print(x)
# Out:
# 2026-04-12 11:02:43.464051

# %%
import datetime

x = datetime.datetime.now()
print(x.date())    # get only date
# Out:
# 2026-04-12

# %%
import datetime
x = datetime.datetime.now()
print(x.time())
# Out:
# 11:07:56.744318

# %%
import datetime

x = datetime.datetime.now()

print(x.year)
print(x.month)
print(x.day)
# Out:
# 2026
# 4
# 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import datetime

x = datetime.datetime.now()
print(x.strftime("%A"))
# Out:
# Sunday

# %% [markdown]
# # Math Module

# %%
import math

print(math.sqrt(16))   # square root
print(math.ceil(4.2))  # round up
print(math.floor(4.8)) # round down
# Out:
# 4.0
# 5
# 4

# %%
import math

print(math.pow(2, 3))  # 2^3
print(abs(-10))        # absolute value
# Out:
# 8.0
# 10

# %%
import math

print(math.pi)
# Out:
# 3.141592653589793

# %%
import math

print(math.sin(0))
print(math.cos(0))
# Out:
# 0.0
# 1.0

# %%
import math

print(math.factorial(5))
# Out:
# 120

# %% [markdown]
# without math module

# %%
print(max(1, 5, 3))
print(min(1, 5, 3))
print(pow(2, 3))
# Out:
# 5
# 1
# 8
