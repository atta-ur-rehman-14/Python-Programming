# %% [markdown]
# # conditional statements
# - if internet avaliable --> Class will be held
# - if internet not avaliable --> Class will not be conducted

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
internet_avaliable = False
independence_day = "no"

if internet_avaliable and independence_day == "yes":
    print("watch independence event:")
elif internet_avaliable:
    print("class will be held online")
else:
    print("class will not held")
# Out:
# class will not held

# %%
marks = 40

if marks > 80:

    print("Your Grade is A")

elif marks > 60 and marks <= 80:

    print("Your Grade is B")

elif marks > 50 and marks <= 60:

    print("Your Grade is C")
elif marks > 40 and marks <=30:
    print("Your Grade is D")
elif marks > 30 and marks <=40:
    print("Your grade is E")
# Out:
# Your grade is E

# %%
num= 4
if num % 2 ==0:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %% [markdown]
# # List

# %%
student_number = [10,20,30,40,50] # elements of integers in list
Cities = ["Lahore","Faisalabad","Karachi"] # elements of string in list
Bollean_list = [True,False] # element of boolean in list
My_Info= ["Atta","Ur","Rehman",22,"BSCS"] # list with different data types

print(Cities)
# Out:
# ['Lahore', 'Faisalabad', 'Karachi']

# %%
Subject =["Math","English","Urdu","Isl","Computer"]
marks =[40,35,80,70,90]
# index [0,1,2,3,4]
print(marks)
# Out:
# [40, 35, 80, 70, 90]

# %% [markdown]
# # Tuple

# %% [markdown]
# Tuples are ordered collection of data items. They store multiple items in a single in a single variable.Tuple items are separated by commas and enclosed within round brackets (). Tuples are Unchangeable means that we cant't alter them after creation.

# %% [markdown]
# # Indexing

# %%
print(marks[0])
marks[1]
# Out:
# 40
# 35

# %% [markdown]
# # Negative Indexing

# %%
roll_number = [1,2,3,4,5]
# Right to left
# negative indexing [-5,-4,-3,-2,-1]
print(roll_number[-2])
# Out:
# 4

# %% [markdown]
# # Append

# %%
student= ["Atta","Waqas","Ahmad"]

# %%
student.append("Haider") # Append add element at the end of the list
print(student)
# Out:
# ['Atta', 'Waqas', 'Ahmad', 'Haider']

# %%
student.append("Nadeem")
print(student)
# Out:
# ['Atta', 'Waqas', 'Ahmad', 'Haider', 'Nadeem', 'Nadeem']

# %% [markdown]
# ### POP

# %%
student.pop() # POP add element at the end of the list
print(student) # - remove element by using index
# Out:
# ['Atta', 'Waqas', 'Ahmad', 'Haider', 'Nadeem']

# %%
student.pop() # POP add element at the end of the list
print(student)
# Out:
# ['Atta', 'Waqas', 'Ahmad', 'Haider']

# %%
student.pop(2) # POP add element at the end of the list
print(student)
# Out:
# ['Atta', 'Waqas', 'Haider']

# %% [markdown]
# ### Remove

# %%
marks.remove(35) # remove element from the list
print(marks) # remove element by using value
# Out:
# [40, 80, 70, 90]

# %% [markdown]
# ### Insert

# %%
num= [1,2,3,4,5]
num.insert(2,10)
print(num)
# Out:
# [1, 2, 10, 3, 4, 5]

# %%
num.insert(5,100)
print(num)
# Out:
# [1, 2, 10, 3, 4, 100, 5]

# %% [markdown]
# ### Agregate Functions

# %%
print(sum(marks))
# Out:
# 315

# %%
print(max(marks))
# Out:
# 90

# %%
print(min(marks))
# Out:
# 35

# %%
print(len(marks))
# Out:
# 5

# %%
print(sorted(marks))
# Out:
# [35, 40, 70, 80, 90]

# %% [markdown]
# # Slicing

# %%
Country1 = "Pakistan"
Country2 = "India"
Country3 = "Bangladesh"
Country4 = "Afghanistan"

# %%
print(Country3)
# Out:
# Bangladesh

# %%
Countries = ["Pakistan","India","Bangladesh","Afghanistan","Chaina","Dubai"]

# %%
print(type(Countries),Countries)
# index      0         1         2            3         4          5
#       ["Pakistan","India","Bangladesh","Afghanistan","Chaina","Dubai",]
# Out:
# <class 'list'> ['Pakistan', 'India', 'Bangladesh', 'Afghanistan', 'Chaina', 'Dubai']

# %%
Countries.index("Afghanistan")
# Out:
# 3

# %%
# first_value = included 
# last_value = Excluded
# Syntax
# list_name= [start(included):end(excluded)]
Countries[0:3]
# Out:
# ['Pakistan', 'India', 'Bangladesh']

# %%
Countries[:] # single colom means all element of list will be printed
# Out:
# ['Pakistan', 'India', 'Bangladesh', 'Afghanistan', 'Chaina', 'Dubai']

# %%
Countries[:3] # first 3 element of the list will be printed
# Out:
# ['Pakistan', 'India', 'Bangladesh']

# %%
Countries[2:] # elemnt from index 2 to end will be printed
# Out:
# ['Bangladesh', 'Afghanistan', 'Chaina', 'Dubai']

# %%
Countries[0:3:2] # element from index 0 to 3 with step 2 will be printed
# Out:
# ['Pakistan', 'Bangladesh']

# %%
Countries[::2]
# Out:
# ['Pakistan', 'Bangladesh', 'Chaina']

# %% [markdown]
# # Negative Indexing

# %%
# Positive index      0         1         2            3         4          5 
#                ["Pakistan","India","Bangladesh","Afghanistan","Chaina","Dubai",]
# Negative Index    -6          -5        -4        -3           -2         -1

# %%
Countries[-4]
# Out:
# 'Bangladesh'

# %%
Countries[-6:-1]
# Out:
# ['Pakistan', 'India', 'Bangladesh', 'Afghanistan', 'Chaina']

# %%
Countries[-6:-1:2]
# Out:
# ['Pakistan', 'Bangladesh', 'Chaina']

# %% [markdown]
# ### Task

# %%
number = [1,2,3,4,5,6,7,8,9,0]

# %% [markdown]
# #### print number 4,5,6

# %%
number[3:6]
# Out:
# [4, 5, 6]

# %% [markdown]
# ### print even number

# %%
number[1::2]
# Out:
# [2, 4, 6, 8, 0]

# %% [markdown]
# ### print even number in reverse order

# %%
number[::-2]
# Out:
# [0, 8, 6, 4, 2]

# %% [markdown]
# ### print odd numbers

# %%
number[0::2]
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ### print odd number in reverse order

# %%
number[-2::-2]
# Out:
# [9, 7, 5, 3, 1]

# %% [markdown]
# # Tuples

# %%
Tuple = (1,2,3,4,5,6,7,8,9,0)

# %%
type(Tuple)
# Out:
# tuple

# %% [markdown]
# Because of immutablility tuple will show errors

# %%
Tuple[0]= 10 # Tuple is immutable data type, we cannot change the value of tuple
             # TypeError: 'tuple' object does not support item assignment
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Tuple[0]= 10 # Tuple is immutable data type, we cannot change the value of tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
Tuple.append(10) # AttributeError: 'tuple' object has no attribute 'append'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Tuple.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
Tuple[1:3]
# Out:
# (2, 3)

# %% [markdown]
# # Task

# %% [markdown]
# 1. Show the Even number using slicing method and then also show Even numbers in reverse order
# 2. Show the Odd number using slicing method and then also show Odd numbers in reverse order

# %%
Tuple[1:9:2]
# Out:
# (2, 4, 6, 8)

# %%
Tuple[-1::-2]
# Out:
# (0, 8, 6, 4, 2)

# %%
Tuple[0::2]
# Out:
# (1, 3, 5, 7, 9)

# %%
Tuple[-2::-2]
# Out:
# (9, 7, 5, 3, 1)
